# %% [markdown]
# ## Valid Soduku
# #### Difficulty: Medium
#
#
# Determine if a 9 x 9 Sudoku board is valid. Only the filled cells need to be validated according to the following rules:
#
# Each row must contain the digits 1-9 without repetition.
# Each column must contain the digits 1-9 without repetition.
# Each of the nine 3 x 3 sub-boxes of the grid must contain the digits 1-9 without repetition.
# Note:
#
# A Sudoku board (partially filled) could be valid but is not necessarily solvable.
# Only the filled cells need to be validated according to the mentioned rules.
#
# Constraints:
# - `board.length == 9`
# - `board[i].length == 9`
# - `board[i][j]` is a digit `1-9` or `'.'`.
#
# Link to problem: https://leetcode.com/problems/valid-sudoku/

# %%
# 1st implementation. Uses little memory and has good run time. Not very concise.
# Surely there is a more concise way of implementing this. Will revisit.

def isValidSudoku(self, board):
       """
       :type board: List[List[str]]
       :rtype: bool
       """
       ''' 
       Given: Board - 2D array with length & width == 9.
       Required: Is board valid?
              - Is there no duplicates in each row?
              - Is there no duplicates in each column?
              - Is there no duplicates in each 3x3 box?
       '''
       # Check rows
       for row in board:
              # Init new count
              seen = set()

              # Iterate through row
              for num in row:
                     if num != ".":      
                            if num in seen: 
                                   return False
                            seen.add(num)

       # Check columns       
       for column in range(9):
              # Init new count
              seen = set()

              for row in board:
                     num = row[column]
                     if num != ".":
                            if num in seen:
                                   return False
                     seen.add(num)
                     
       # Iterate 3x3 boxes by incrementing start rows & columns by 3
       for start_row in range(0, 9, 3):
              for start_col in range(0, 9, 3):
                     # Init new count
                     seen = set()

                     # Check 3x3 boxes
                     for row in range(3):
                            for col in range(3):
                                   num = board[start_row + row][start_col + col]
                                   if num != ".":
                                          if num in seen:
                                                 return False
                                          seen.add(num)
       
       # If no duplicates, return true              
       return True

# %% [markdown]
# Results:
#
# ![image.png](attachment:image.png)
